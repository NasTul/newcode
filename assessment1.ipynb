# %%
from datasets import load_dataset

# %%
#####

# %%
dataset = load_dataset("hanxiguo/codemirage")
dataset = dataset["train"]  # or "test", "validation" as needed
print(dataset)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-c41438a6bdc5> in <cell line: 0>()
# ----> 1 dataset = load_dataset("hanxiguo/codemirage")
#       2 dataset = dataset["train"]  # or "test", "validation" as needed
#       3 print(dataset)
#
# ...

# %%
import pandas as pd

# Login using e.g. `huggingface-cli login` to access this dataset
splits = {'train': 'train.csv', 'test': 'test.csv'}
df = pd.read_csv("hf://datasets/HanxiGuo/CodeMirage/" + splits["train"])

# %%
df
# Out:
#                                                      code language  \
# 0       """\nSupport for EnOcean binary sensors.\n\nFo...   Python
# 1       # Copyright 2017 The TensorFlow Authors. All R...   Python
# 2       # -*- coding: utf-8 -*-\n\n#  ..#######.######...   Python
# 3       ##############################################...   Python
# 4       from .model import NetworkModel\nfrom .view im...   Python
# ...                                                   ...      ...
# 146987  <!DOCTYPE html>\n<html lang="en">\n<head>\n   ...     HTML
# 146988  <!DOCTYPE html>\n<html ng-app="dataCollectorAp...     HTML
# 146989  <!DOCTYPE html>\n<html lang="en">\n<head>\n   ...     HTML
# 146990  <!DOCTYPE html>\n<html lang="en">\n<head>\n   ...     HTML
# 146991  <!DOCTYPE html>\n<html lang="en">\n<head>\n   ...     HTML
#
#                source      variant
# 0               Human          NaN
# 1               Human          NaN
# 2               Human          NaN
# ...

# %%
import pandas as pd

# Login using e.g. `huggingface-cli login` to access this dataset
splits = {'train': 'data.parquet', 'test': 'test.csv'} # Assuming test.csv is correct, if not, please provide the correct name
ds = pd.read_parquet("hf://datasets/researchartifact1234/CoRe/" + splits["train"])

# %%
ds
# Out:
#                                        label_file  \
# 0      codenet_p00122_s821876806_isSafe_9_32.yaml
# 1      codenet_p00122_s821876806_isSafe_9_32.yaml
# 2      codenet_p00122_s821876806_isSafe_9_32.yaml
# 3       codenet_p00829_s829617336_main_16_38.yaml
# 4       codenet_p00829_s829617336_main_16_38.yaml
# ...                                           ...
# 14134             gcj_459f2_4981c_solve_1_67.yaml
# 14135             gcj_459f2_4981c_solve_1_67.yaml
# 14136             gcj_459f2_4981c_solve_1_67.yaml
# 14137             gcj_459f2_4981c_solve_1_67.yaml
# 14138             gcj_459f2_4981c_solve_1_67.yaml
#
#                                       code_file     pid         sid funname  \
# 0      codenet_p00122_s821876806_isSafe_9_32.py  p00122  s821876806  isSafe
# 1      codenet_p00122_s821876806_isSafe_9_32.py  p00122  s821876806  isSafe
# 2      codenet_p00122_s821876806_isSafe_9_32.py  p00122  s821876806  isSafe
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import binascii, io, os, subprocess, json, base64, struct

# %%
# load image
img_path="./Document.pdf"
with open(img_path,'rb') as f:
    data=f.read()
print(len(data))
# check for text 'pecan{' inside bytes
print("pecan{" in data.decode('latin1'))
# Out:
# 11136
# False

# %%
data.decode('latin1')
# Out:
# 'ÿØÿà\x00\x10JFIF\x00\x01\x01\x01\x00`\x00`\x00\x00ÿá\x10ÒExif\x00\x00MM\x00*\x00\x00\x00\x08\x00\t\x01\x0e\x00\x02\x00\x00\x00\x13\x00\x00\x07ô\x01;\x00\x02\x00\x00\x00\x0f\x00\x00\x07z\x87i\x00\x04\x00\x00\x00\x01\x00\x00\x08j\x9c\x9b\x00\x01\x00\x00\x00&\x00\x00\x07Î\x9c\x9c\x00\x01\x00\x00\x00B\x00\x00\x08\x08\x9c\x9d\x00\x01\x00\x00\x00\x1e\x00\x00\x07\\\x9c\x9e\x00\x01\x00\x00\x00"\x00\x00\x07¬\x9c\x9f\x00\x01\x00\x00\x00"\x00\x00\x07\x8aê\x1c\x00\x07\x00\x00\x06â\x00\x00\x00z\x00\x00\x00\x00\x1cê\x
# ...

# %%
idx=data.find(b'pecan{')
data[idx:idx+80]
# Out:
# b'pecan{DaYDr3am1n_1n-Th3_Cl0ud5}\x00\x00\x01\xea\x1c\x00\x07\x00\x00\x08\x0c\x00\x00\x08|\x00\x00\x00\x00\x1c\xea\x00\x00\x00\x08\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'
